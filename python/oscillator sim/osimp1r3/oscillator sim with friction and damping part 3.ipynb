# %%
#Round 3: Only Coulomb friction
#The differential equation is ma = -kx - mu*mg*sign(v) -> mx'' + kx + mu*mg*sgn(x')=0
#dx=v, dv = -(k/m)x - mu*g*sgn(x')
#Let's use the same mass and spring constant m=3 kg and k=108 N/m. The initial position and velocity will both be 1.
#We want noticeable change in the total mechanical energy of the system. Since the change in the mechanical energy is the work done by nonconservative forces, we can say delta E = int(f)ds. If there were no nonconservative forces, the total mechanical energy of the system would be K+U = .5*3*1 + .5*108*1 = .6+54=54.6 J (this checks out with what we see in P1R1). Using the position graph from P1R1, using a change of 4 J in one-half cycle gives us a good mu value of .067. More work on Desmos (linked in slideshow or GitHub). I will most likely shift the friction constant around to attain more energy loss later.

# %%
# %matplotlib inline
# %matplotlib notebook

#important: we won't use analytic solutions because that will require piecewise nonsense and 1) I am too lazy for that, and 2) I am not even sure that python supports piecewise functions without some super niche module

import numpy as np
import matplotlib.pyplot as plt

#values
N=1000
h=.01
m=3
mu=.067
k=108
#a=something #make sure to actually add these
#num_cycles=something

t=np.zeros(N)
t[0]=0

x=np.zeros(N)
x[0]=1

v=np.zeros(N)
v[0]=1

state = np.array([x[0],v[0]])

K=np.zeros(N) #energies
U=np.zeros(N)
E=np.zeros(N)
e_loss=[]

max_amps=[]
min_amps=[]

# %%
# %matplotlib inline
# %matplotlib notebook

#functions here
